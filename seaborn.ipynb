# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilkoduvalli/Machine_Learning/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #seaborn is a library that used for data visualization,it is more prefered tgan matplotlb

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#correlation
#Correlation is a statistical measure that expresses the extent to which two variables are linearly related

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#heat map
#heat map is used to represent the correlationship by using seaborn library

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
# joinplot


sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='size',y='total_bill',data=df)

# %%
#pairplot

sns.pairplot(df,hue='smoker')

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
for i in df.columns:
    # Create a new figure for each column
    plt.figure(figsize=(8, 4))  # Set the size of the figure
    sns.countplot(x=i, data=df)  # Generate a count plot

# %%
 #countplot

sns.countplot(x='sex',data=df,hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='time',data=df)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='day',data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time',data=df)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
for i in df.columns:
  plt.figure(figsize=(8,4))
  print(sns.barplot(x='total_bill',y=i,data=df))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.barplot(x='total_bill',y='sex',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.barplot(x='total_bill',y='time',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %%
   # boxplot
sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
def removel_box_plot(df, column, threshold):
  sns.boxplot(df[column])
  plt.title(f'original boxplot of {column}')
  plt.sow()

  removed_outliers = df[df[column] < threshold]

  sns.boxplot(removed_outliers[column])
  plt.title(f'boxplot of {column} after removing outliers')
  plt.show()

  return removed_outliers

  threshold=40
  no_outliers_df=removel_box_plot(df,'total_bill',threshold)

# %%
import numpy as np
Q1=np.percentile(df['total_bill'],25,method='midpoint')
Q3=np.percentile(df['total_bill'],75,method='midpoint')
IQR=Q3-Q1
print(IQR)
# Out:
# 10.849999999999998

# %%
upper=Q3+1.5*IQR
upper_array=np.array(df['total_bill']>=upper)
print('Upper_Bound:',upper)
print(upper_array.sum())

lower=Q1-1.5*IQR
lower_array=np.array(df['total_bill'])<=lower
print('Lower Bound:',lower)
print(lower_array.sum())
# Out:
# Upper_Bound: 40.449999999999996
# 9
# Lower Bound: -2.9499999999999993
# 0
